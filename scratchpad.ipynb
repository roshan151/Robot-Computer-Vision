# %%
from __future__ import annotations

import argparse
import time
from drivetrain_client import SerialDrivetrain

port, baud = "/dev/cu.usbserial-A5069RR4", 115200
drivetrain = SerialDrivetrain(port=port, baud=baud)
drivetrain.intent_right()
time.sleep(2)
drivetrain.stop()
